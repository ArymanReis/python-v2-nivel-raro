# %%
import pandas as pd

# %%
# 1. Criamos um dicionário com os nossos dados
dados_fazenda = {
    "Meses": ["Jan", "Fev", "Mar", "Abr", "Mai"],
    "Safra_KG": [1500, 2300, 1800, 3100, 2000],
    "Faturamento_R$": [15000, 23000, 18000, 31000, 20000]
}

# 2. Transformamos o dicionário na Planilha Oficial (DataFrame)
tabela_fazenda = pd.DataFrame(dados_fazenda)

print(tabela_fazenda)
# Out:
#   Meses  Safra_KG  Faturamento_R$
# 0   Jan      1500           15000
# 1   Fev      2300           23000
# 2   Mar      1800           18000
# 3   Abr      3100           31000
# 4   Mai      2000           20000

# %%
import pandas as pd

# %%
# O comando mágico que lê o arquivo e cria o DataFrame
tabela_importada = pd.read_csv("../BASE-DADOS/safra.csv")

# Exibindo a tabela
print(tabela_importada)
# Out:
#   Meses  Safra_KG  Faturamento_RS
# 0   Jan      1500           15000
# 1   Fev      2300           23000
# 2   Mar      1800           18000
# 3   Abr      3100           31000
# 4   Mai      2000           20000

# %%
tabela_importada.head(n=5)
# Out:
#   Meses  Safra_KG  Faturamento_RS
# 0   Jan      1500           15000
# 1   Fev      2300           23000
# 2   Mar      1800           18000
# 3   Abr      3100           31000
# 4   Mai      2000           20000

# %%
tabela_importada.shape
# Out:
# (5, 3)

# %%
tabela_importada.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Meses           5 non-null      str
#  1   Safra_KG        5 non-null      int64
#  2   Faturamento_RS  5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes

# %%
import pandas as pd

# %%
# O comando mágico que lê o arquivo e cria o DataFrame
tabela_importada = pd.read_csv("safra.csv")

# Exibindo a tabela
print(tabela_importada)
# Out:
#   Meses  Safra_KG  Faturamento_RS
# 0   Jan      1500           15000
# 1   Fev      2300           23000
# 2   Mar      1800           18000
# 3   Abr      3100           31000
# 4   Mai      2000           20000

# %%
import pandas as pd

# %%
# Uma simples lista de Python
dados_safra = [1500, 2300, 1800, 3100, 2000]

# Transformando a lista em uma Pandas Series
coluna_safra = pd.Series(dados_safra)

print(coluna_safra)
# Out:
# 0    1500
# 1    2300
# 2    1800
# 3    3100
# 4    2000
# dtype: int64

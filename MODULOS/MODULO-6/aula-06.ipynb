# %%
import pandas as pd

# Carregando a nossa base de dados
df = pd.read_csv("../BASE-DADOS/safra.csv")

# %%
# Passo 1: Escrevemos a Condição
condicao_elite = df['Safra_KG'] > 2000

# Passo 2: Colocamos a condição dentro da tabela (df)
safras_elite = df[condicao_elite]

# Exibindo o resultado final
safras_elite.head()
# Out:
#   Meses  Safra_KG  Faturamento_RS
# 1   Fev      2300           23000
# 3   Abr      3100           31000
